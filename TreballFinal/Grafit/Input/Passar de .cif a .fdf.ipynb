# %%
# !pip install ase
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from ase.io import read, write

# %%
# Carga el archivo CIF
archivo_cif = 'C.cif'
atomos = read(archivo_cif, format='cif')

# %%
# Guarda la estructura como XYZ
archivo_xyz = 'structure.xyz'
write(archivo_xyz, atomos, format='xyz')

# %%
from sisl import*

# %%
molecule=Geometry.read("structure.xyz")
molecule.write("structure.fdf")
